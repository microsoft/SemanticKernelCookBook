// %%
%dependency /add com.azure:azure-ai-openai:1.0.0-beta.7
// %dependency /add com.azure:azure-identity:1.11.3
%dependency /add org.slf4j:slf4j-simple:1.7.36
%dependency /resolve
// Out:
// Adding dependency com.azure:azure-ai-openai:1.0.0-beta.7
// Adding dependency org.slf4j:slf4j-simple:1.7.36
// Solving dependencies
// Found dependencies count: 35
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/com.azure/azure-ai-openai/jars/azure-ai-openai-1.0.0-beta.7.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/com.azure/azure-core/jars/azure-core-1.47.0.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/com.azure/azure-json/jars/azure-json-1.1.0.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/com.fasterxml.jackson.core/jackson-annotations/bundles/jackson-annotations-2.13.5.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/com.fasterxml.jackson.core/jackson-core/bundles/jackson-core-2.13.5.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/com.fasterxml.jackson.core/jackson-databind/bundles/jackson-databind-2.13.5.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/com.fasterxml.jackson.datatype/jackson-datatype-jsr310/bundles/jackson-datatype-jsr310-2.13.5.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/org.slf4j/slf4j-api/jars/slf4j-api-1.7.36.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.projectreactor/reactor-core/jars/reactor-core-3.4.34.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/org.reactivestreams/reactive-streams/jars/reactive-streams-1.0.4.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/com.azure/azure-core-http-netty/jars/azure-core-http-netty-1.14.1.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-handler/jars/netty-handler-4.1.101.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-common/jars/netty-common-4.1.101.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-resolver/jars/netty-resolver-4.1.101.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-buffer/jars/netty-buffer-4.1.101.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-transport/jars/netty-transport-4.1.101.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-transport-native-unix-common/jars/netty-transport-native-unix-common-4.1.101.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-codec/jars/netty-codec-4.1.101.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-handler-proxy/jars/netty-handler-proxy-4.1.101.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-codec-socks/jars/netty-codec-socks-4.1.101.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-codec-http/jars/netty-codec-http-4.1.101.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-codec-http2/jars/netty-codec-http2-4.1.101.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-transport-native-epoll/jars/netty-transport-native-epoll-4.1.101.Final-linux-x86_64.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-transport-classes-epoll/jars/netty-transport-classes-epoll-4.1.101.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-transport-native-kqueue/jars/netty-transport-native-kqueue-4.1.101.Final-osx-x86_64.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-transport-classes-kqueue/jars/netty-transport-classes-kqueue-4.1.101.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-tcnative-boringssl-static/jars/netty-tcnative-boringssl-static-2.0.62.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-tcnative-classes/jars/netty-tcnative-classes-2.0.62.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.projectreactor.netty/reactor-netty-http/jars/reactor-netty-http-1.0.40.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-resolver-dns/jars/netty-resolver-dns-4.1.101.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-codec-dns/jars/netty-codec-dns-4.1.101.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-resolver-dns-native-macos/jars/netty-resolver-dns-native-macos-4.1.101.Final-osx-x86_64.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-resolver-dns-classes-macos/jars/netty-resolver-dns-classes-macos-4.1.101.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.projectreactor.netty/reactor-netty-core/jars/reactor-netty-core-1.0.40.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/org.slf4j/slf4j-simple/jars/slf4j-simple-1.7.36.jar

// %%
import com.azure.ai.openai.OpenAIAsyncClient;
import com.azure.ai.openai.OpenAIClientBuilder;
import com.azure.ai.openai.models.Choice;
import com.azure.ai.openai.models.Completions;
import com.azure.ai.openai.models.CompletionsOptions;
import com.azure.ai.openai.models.CompletionsUsage;

// %%
String AZURE_KEY = "Your Azure OpenAI Service API Key";
String AZURE_ENDPOINT = "Your Azure OpenAI Service Endpoint";

// %%
import com.azure.core.credential.AzureKeyCredential;

// %%
OpenAIAsyncClient client = new OpenAIClientBuilder()
        .credential(new AzureKeyCredential(AZURE_KEY))
        .endpoint(AZURE_ENDPOINT)
        .buildAsyncClient();

// %%
List<String> prompt = new ArrayList<>();
prompt.add("How to learn AI");
// Out:
// true

// %%
var completionsOptions = new CompletionsOptions(prompt);

// %%
completionsOptions.setTemperature(0.8);
completionsOptions.setMaxTokens(10000);
// Out:
// com.azure.ai.openai.models.CompletionsOptions@41661281

// %%
var completions = client.getCompletions("Your Azure OpenAI Service gpt-3.5-turbo-instruct deployment name", completionsOptions);

// %%
for (Choice choice : completions.block().getChoices()) {
    System.out.println(choice.getText());
}
// Out:
// 1. Understand the basics of AI: AI (Artificial Intelligence) is a broad field that encompasses many different technologies and techniques. Some of the key concepts to understand include machine learning, neural networks, natural language processing, and robotics.
//
// 2. Take online courses or attend classes: There are many online courses available that teach the fundamentals of AI. Coursera, Udemy, and edX offer a variety of courses, both free and paid, that cover topics such as machine learning, deep learning, and data science. You can also enroll in classes at a local university or community college to get a more hands-on learning experience.
//
// 3. Learn programming languages commonly used in AI: Familiarize yourself with programming languages that are commonly used in AI, such as Python, R, and Java. These languages are used for data analysis, machine learning, and building AI applications.
//
// 4. Practice with AI tools and platforms: There are many tools and platforms available that can help you practice and apply your AI knowledge. Some popular options include TensorFlow, PyTorch, and Keras for machine learning, and NLTK for natural language processing.
//
// 5. Join AI communities and participate in discussions: Connect with others who are interested in AI and join online communities to learn from others, ask questions, and share your knowledge. Some popular communities include Reddit’s r/artificial, Quora, and LinkedIn groups.
//
// 6. Read books and articles on AI: There are many books and articles available that cover various aspects of AI. Some recommended titles include “Artificial Intelligence: A Modern Approach” by Stuart Russell and Peter Norvig, “Superintelligence” by Nick Bostrom, and “The Singularity Is Near” by Ray Kurzweil.
//
// 7. Work on personal projects: A great way to learn AI is by working on personal projects. Choose a problem or idea that interests you and apply your AI knowledge to solve it. This will give you hands-on experience and help you apply what you have learned.
//
// 8. Attend workshops and conferences: Attending workshops and conferences on AI is a great way to learn from experts, network with like-minded individuals, and stay updated on the latest advancements in the field.
//
// 9. Follow AI influencers and thought leaders: Follow AI experts and thought leaders on social media, read their blogs, and watch their talks and interviews. This will help you stay informed on current trends and developments in AI.
//
// 10. Stay curious and keep learning: As AI is a rapidly evolving field, it’s important to stay curious and keep learning. Continuously seek out new resources and opportunities to expand your knowledge and skills in AI.

// %%
import com.azure.ai.openai.models.ChatChoice;
import com.azure.ai.openai.models.ChatCompletions;
import com.azure.ai.openai.models.ChatCompletionsOptions;
import com.azure.ai.openai.models.ChatRequestMessage;
import com.azure.ai.openai.models.ChatRequestSystemMessage;
import com.azure.ai.openai.models.ChatRequestUserMessage;
import com.azure.ai.openai.models.ChatResponseMessage;
import com.azure.ai.openai.models.ChatRole;

// %%
List<ChatRequestMessage> chatMessages = new ArrayList<>();
chatMessages.add(new ChatRequestSystemMessage("You are a AI teacher."));
chatMessages.add(new ChatRequestUserMessage("Can you explain what is Machine Learning?"));
// Out:
// true

// %%
var chatCompletions = client.getChatCompletions("Your Azure OpenAI Service gpt-3.5-turbo-16k deployment name",
    new ChatCompletionsOptions(chatMessages).setMaxTokens(10000).setTemperature(0.7));

// %%
for (ChatChoice choice : chatCompletions.block().getChoices()) {
    ChatResponseMessage message = choice.getMessage();
    System.out.println(message.getContent());
}
// Out:
// Machine learning is a branch of artificial intelligence (AI) that focuses on the development of algorithms and statistical models that allow computers to learn and make predictions or decisions without being explicitly programmed. The goal of machine learning is to enable computers to learn from and analyze large amounts of data, identify patterns, and make accurate predictions or decisions based on that data.
//
// Machine learning algorithms are designed to automatically learn and improve from experience, without being explicitly programmed for every possible scenario. They use a variety of techniques, such as supervised learning, unsupervised learning, and reinforcement learning, to train models on labeled or unlabeled data, and make predictions or take actions based on the patterns they have learned.
//
// Supervised learning involves training a model using labeled data, where the inputs and desired outputs are provided. The model learns to make predictions by finding patterns in the data and adjusting its internal parameters accordingly.
//
// Unsupervised learning, on the other hand, involves training a model on unlabeled data, where only the inputs are provided. The model learns to identify patterns and structures in the data without any specific guidance on the desired outputs.
//
// Reinforcement learning is a type of machine learning that involves an agent learning to interact with an environment and maximize a reward signal. The agent learns by taking actions, receiving feedback from the environment, and adjusting its behavior based on the received rewards or penalties.
//
// Machine learning has a wide range of applications, including image and speech recognition, natural language processing, recommendation systems, fraud detection, autonomous vehicles, and many others. It enables computers to automate tasks, make accurate predictions, and adapt to changing conditions based on the data they have learned from.

// %%
%dependency /add ai.djl:api:0.22.1
%dependency /add ai.djl.mxnet:mxnet-engine:0.22.1
%dependency /add ai.djl.mxnet:mxnet-model-zoo:0.22.1
%dependency /resolve
// Out:
// Adding dependency ai.djl:api:0.22.1
// Adding dependency ai.djl.mxnet:mxnet-engine:0.22.1
// Adding dependency ai.djl.mxnet:mxnet-model-zoo:0.22.1
// Solving dependencies
// Found dependencies count: 41
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/com.azure/azure-ai-openai/jars/azure-ai-openai-1.0.0-beta.7.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/com.azure/azure-core/jars/azure-core-1.47.0.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/com.azure/azure-json/jars/azure-json-1.1.0.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/com.fasterxml.jackson.core/jackson-annotations/bundles/jackson-annotations-2.13.5.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/com.fasterxml.jackson.core/jackson-core/bundles/jackson-core-2.13.5.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/com.fasterxml.jackson.core/jackson-databind/bundles/jackson-databind-2.13.5.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/com.fasterxml.jackson.datatype/jackson-datatype-jsr310/bundles/jackson-datatype-jsr310-2.13.5.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/org.slf4j/slf4j-api/jars/slf4j-api-1.7.36.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.projectreactor/reactor-core/jars/reactor-core-3.4.34.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/org.reactivestreams/reactive-streams/jars/reactive-streams-1.0.4.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/com.azure/azure-core-http-netty/jars/azure-core-http-netty-1.14.1.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-handler/jars/netty-handler-4.1.101.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-common/jars/netty-common-4.1.101.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-resolver/jars/netty-resolver-4.1.101.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-buffer/jars/netty-buffer-4.1.101.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-transport/jars/netty-transport-4.1.101.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-transport-native-unix-common/jars/netty-transport-native-unix-common-4.1.101.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-codec/jars/netty-codec-4.1.101.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-handler-proxy/jars/netty-handler-proxy-4.1.101.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-codec-socks/jars/netty-codec-socks-4.1.101.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-codec-http/jars/netty-codec-http-4.1.101.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-codec-http2/jars/netty-codec-http2-4.1.101.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-transport-native-epoll/jars/netty-transport-native-epoll-4.1.101.Final-linux-x86_64.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-transport-classes-epoll/jars/netty-transport-classes-epoll-4.1.101.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-transport-native-kqueue/jars/netty-transport-native-kqueue-4.1.101.Final-osx-x86_64.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-transport-classes-kqueue/jars/netty-transport-classes-kqueue-4.1.101.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-tcnative-boringssl-static/jars/netty-tcnative-boringssl-static-2.0.62.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-tcnative-classes/jars/netty-tcnative-classes-2.0.62.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.projectreactor.netty/reactor-netty-http/jars/reactor-netty-http-1.0.40.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-resolver-dns/jars/netty-resolver-dns-4.1.101.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-codec-dns/jars/netty-codec-dns-4.1.101.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-resolver-dns-native-macos/jars/netty-resolver-dns-native-macos-4.1.101.Final-osx-x86_64.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.netty/netty-resolver-dns-classes-macos/jars/netty-resolver-dns-classes-macos-4.1.101.Final.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/io.projectreactor.netty/reactor-netty-core/jars/reactor-netty-core-1.0.40.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/org.slf4j/slf4j-simple/jars/slf4j-simple-1.7.36.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/ai.djl/api/jars/api-0.22.1.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/com.google.code.gson/gson/jars/gson-2.10.1.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/net.java.dev.jna/jna/jars/jna-5.13.0.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/org.apache.commons/commons-compress/jars/commons-compress-1.22.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/ai.djl.mxnet/mxnet-engine/jars/mxnet-engine-0.22.1.jar
// Add to classpath: /home/vscode/.local/share/jupyter/kernels/rapaio-jupyter-kernel/ivy_cache/ai.djl.mxnet/mxnet-model-zoo/jars/mxnet-model-zoo-0.22.1.jar

// %%
import ai.djl.modality.cv.*;
import ai.djl.modality.cv.output.*;
import ai.djl.modality.cv.util.*;
import ai.djl.mxnet.zoo.*;
import ai.djl.repository.zoo.*;
import ai.djl.training.util.*;

// %%
import com.azure.ai.openai.models.ImageGenerationOptions;
import com.azure.ai.openai.models.ImageGenerations;
import com.azure.ai.openai.models.ImageGenerationData;

// %%
ImageGenerationOptions imageGenerationOptions = new ImageGenerationOptions(
    "Chinese New Year picture for the Year of the Dragon");
var images = client.getImageGenerations("Your Azure OpenAI Service dalle-e-3 deployment name", imageGenerationOptions);

String url = images.block().getData().get(0).getUrl();

// %%
url
// Out:
// https://dalleprodsec.blob.core.windows.net/private/images/6e5b8443-8fc6-48d5-8e2c-2006bce375b2/generated_00.png?se=2024-04-14T05%3A54%3A22Z&sig=xBnWWkU0bixkAoR1LvrHsnDzJg0RtMXM%2FMzr2GEC78U%3D&ske=2024-04-19T08%3A03%3A45Z&skoid=e52d5ed7-0657-4f62-bc12-7e5dbb260a96&sks=b&skt=2024-04-12T08%3A03%3A45Z&sktid=33e01921-4d64-4f8c-a055-5bdaffd5e33d&skv=2020-10-02&sp=r&spr=https&sr=b&sv=2020-10-02

// %%
var img = ImageFactory.getInstance().fromUrl(url);
img.getWrappedImage()
